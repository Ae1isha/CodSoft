MB 2.8 MB/s eta 0:00:08
#    --------------------------------- ------ 102.8/123.0 MB 2.8 MB/s eta 0:00:08
#    --------------------------------- ------ 103.5/123.0 MB 2.8 MB/s eta 0:00:07
#    ---------------------------------- ----- 104.6/123.0 MB 2.8 MB/s eta 0:00:07
#    ---------------------------------- ----- 105.4/123.0 MB 2.9 MB/s eta 0:00:07
#    ---------------------------------- ----- 106.2/123.0 MB 2.9 MB/s eta 0:00:06
#    ---------------------------------- ----- 107.2/123.0 MB 2.9 MB/s eta 0:00:06
#    ----------------------------------- ---- 108.0/123.0 MB 2.9 MB/s eta 0:00:06
#    ----------------------------------- ---- 108.8/123.0 MB 2.9 MB/s eta 0:00:05
#    ----------------------------------- ---- 109.6/123.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 110.6/123.0 MB 3.0 MB/s eta 0:00:05
#    ----------------------------------- ---- 110.6/123.0 MB 3.0 MB/s eta 0:00:05
#    ------------------------------------ --- 111.4/123.0 MB 3.0 MB/s eta 0:00:04
#    ------------------------------------ --- 112.5/123.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 113.2/123.0 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------- -- 114.3/123.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 115.1/123.0 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 116.1/123.0 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 117.4/123.0 MB 3.2 MB/s eta 0:00:02
#    -------------------------------------- - 118.5/123.0 MB 3.2 MB/s eta 0:00:02
#    -------------------------------------- - 119.5/123.0 MB 3.2 MB/s eta 0:00:02
#    ---------------------------------------  120.8/123.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  121.9/123.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  122.9/123.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 123.0/123.0 MB 3.3 MB/s  0:00:49
# Downloading torchvision-0.27.0-cp313-cp313-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 5.3 MB/s eta 0:00:01
#    ------- -------------------------------- 0.8/4.1 MB 1.7 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.1 MB 3.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 4.3 MB/s  0:00:00
# Downloading transformers-5.9.0-py3-none-any.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/10.8 MB 6.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/10.8 MB 6.6 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/10.8 MB 6.4 MB/s eta 0:00:02
#    ------------------ --------------------- 5.0/10.8 MB 5.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.5/10.8 MB 5.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.0/10.8 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 6.6/10.8 MB 4.5 MB/s eta 0:00:01
#    --------------------------- ------------ 7.3/10.8 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.8 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.8 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.8 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/10.8 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/10.8 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 3.7 MB/s  0:00:02
# Downloading huggingface_hub-1.16.1-py3-none-any.whl (668 kB)
#    ---------------------------------------- 0.0/668.2 kB ? eta -:--:--
#    ---------------------------------------- 668.2/668.2 kB 3.0 MB/s  0:00:00
# Downloading hf_xet-1.5.0-cp37-abi3-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 3.5 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/4.0 MB 3.3 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/4.0 MB 3.3 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/4.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/4.0 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  3.9/4.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 2.9 MB/s  0:00:01
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 3.3 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.7 MB 2.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.7 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 3.0 MB/s  0:00:00
# Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, regex, hf-xet, torch, torchvision, huggingface-hub, tokenizers, transformers
#
#   Attempting uninstall: regex
#
#     Found existing installation: regex 2025.9.1
#
#     Uninstalling regex-2025.9.1:
#
#    ----- ---------------------------------- 1/8 [regex]
#       Successfully uninstalled regex-2025.9.1
#    ----- ---------------------------------- 1/8 [regex]
#    ----- ---------------------------------- 1/8 [regex]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    --------------- ------------------------ 3/8 [torch]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    -------------------- ------------------- 4/8 [torchvision]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------- -------------- 5/8 [huggingface-hub]
#    ------------------------------ --------- 6/8 [tokenizers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ----------------------------------- ---- 7/8 [transformers]
#    ---------------------------------------- 8/8 [transformers]
#
# Successfully installed hf-xet-1.5.0 huggingface-hub-1.16.1 regex-2026.5.9 safetensors-0.7.0 tokenizers-0.22.2 torch-2.12.0 torchvision-0.27.0 transformers-5.9.0

# %%
import torch
from transformers import VisionEncoderDecoderModel
from transformers import ViTImageProcessor
from transformers import AutoTokenizer
from PIL import Image

model_name = "nlpconnect/vit-gpt2-image-captioning"

model = VisionEncoderDecoderModel.from_pretrained(model_name)

feature_extractor = ViTImageProcessor.from_pretrained(model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)

image = Image.open("dog.jpg")

pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values

output_ids = model.generate(pixel_values)

caption = tokenizer.decode(output_ids[0], skip_special_tokens=True)

print("Generated Caption:")
print(caption)
# Out:
# Loading weights:   0%|          | 0/445 [00:00<?, ?it/s]
# [transformers] VisionEncoderDecoderModel LOAD REPORT from: nlpconnect/vit-gpt2-image-captioning
# Key                                                       | Status     |  |
# ----------------------------------------------------------+------------+--+-
# decoder.transformer.h.{0...11}.crossattention.masked_bias | UNEXPECTED |  |
# decoder.transformer.h.{0...11}.attn.masked_bias           | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Generated Caption:
# a dog with a white collar standing in a field
